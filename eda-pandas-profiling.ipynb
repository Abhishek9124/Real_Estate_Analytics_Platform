# %%
import pandas as pd
from ydata_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("output_report.html")
# Out:
#             <div>
#                 <ins><a href="https://ydata.ai/register">Upgrade to ydata-sdk</a></ins>
#                 <p>
#                     Improve your data and profiling with ydata-sdk, featuring data quality scoring, redundancy detection, outlier identification, text validation, and synthetic data generation.
#                 </p>
#             </div>
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# 100%|██████████| 23/23 [00:00<00:00, 37.40it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl.metadata (21 kB)
# Collecting joblib~=1.1.0 (from pandas-profiling)
#   Downloading joblib-1.1.1-py2.py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (2.2.2)
# Requirement already satisfied: matplotlib>=3.2.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=1.8.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (2.8.2)
# Requirement already satisfied: PyYAML>=5.0.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (6.0.2)
# Requirement already satisfied: jinja2>=2.11.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (3.1.6)
# Collecting markupsafe~=2.1.1 (from pandas-profiling)
#   Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl.metadata (3.1 kB)
# Collecting visions==0.7.4 (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading visions-0.7.4-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: numpy>=1.16.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (1.26.4)
# Collecting htmlmin>=0.1.12 (from pandas-profiling)
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting missingno>=0.4.2 (from pandas-profiling)
#   Downloading missingno-0.5.2-py3-none-any.whl.metadata (639 bytes)
# Collecting phik>=0.11.1 (from pandas-profiling)
#   Downloading phik-0.12.5-cp312-cp312-win_amd64.whl.metadata (5.6 kB)
# Collecting tangled-up-in-unicode==0.2.0 (from pandas-profiling)
#   Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: requests>=2.24.0 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (2.32.4)
# Requirement already satisfied: tqdm>=4.48.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (4.66.5)
# Requirement already satisfied: seaborn>=0.10.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas-profiling) (0.13.2)
# Collecting multimethod>=1.4 (from pandas-profiling)
#   Downloading multimethod-2.0-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\admin\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from visions==0.7.4->visions[type_image_path]==0.7.4->pandas-profiling) (3.3)
# Collecting imagehash (from visions[type_image_path]==0.7.4->pandas-profiling)
#   Downloading ImageHash-4.3.2-py2.py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: Pillow in c:\users\admin\anaconda3\lib\site-packages (from visions[type_image_path]==0.7.4->pandas-profiling) (10.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.2.0->pandas-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from matplotlib>=3.2.0->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,!=1.1.0,>=0.25.3->pandas-profiling) (2023.3)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=1.8.1->pandas-profiling) (4.14.1)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.2.0->pandas-profiling) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests>=2.24.0->pandas-profiling) (2025.8.3)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python312\site-packages (from tqdm>=4.48.2->pandas-profiling) (0.4.6)
# Requirement already satisfied: PyWavelets in c:\users\admin\anaconda3\lib\site-packages (from imagehash->visions[type_image_path]==0.7.4->pandas-profiling) (1.7.0)
# Downloading pandas_profiling-3.2.0-py2.py3-none-any.whl (262 kB)
# Downloading tangled_up_in_unicode-0.2.0-py3-none-any.whl (4.7 MB)
#    ---------------------------------------- 0.0/4.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.7 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.7 MB 1.7 MB/s eta 0:00:03
#    -------- ------------------------------- 1.0/4.7 MB 1.8 MB/s eta 0:00:03
#    ------------- -------------------------- 1.6/4.7 MB 2.0 MB/s eta 0:00:02
#    --------------- ------------------------ 1.8/4.7 MB 1.9 MB/s eta 0:00:02
#    ------------------- -------------------- 2.4/4.7 MB 1.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.6/4.7 MB 1.9 MB/s eta 0:00:02
#    -------------------------- ------------- 3.1/4.7 MB 1.9 MB/s eta 0:00:01
#    ------------------------------- -------- 3.7/4.7 MB 2.0 MB/s eta 0:00:01
#    --------------------------------- ------ 3.9/4.7 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 4.5/4.7 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.7/4.7 MB 1.9 MB/s  0:00:02
# Downloading visions-0.7.4-py3-none-any.whl (102 kB)
# Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Downloading MarkupSafe-2.1.5-cp312-cp312-win_amd64.whl (17 kB)
# Downloading missingno-0.5.2-py3-none-any.whl (8.7 kB)
# Downloading multimethod-2.0-py3-none-any.whl (9.8 kB)
# Downloading phik-0.12.5-cp312-cp312-win_amd64.whl (676 kB)
#    ---------------------------------------- 0.0/676.2 kB ? eta -:--:--
#    --------------- ------------------------ 262.1/676.2 kB ? eta -:--:--
#    ---------------------------------------- 676.2/676.2 kB 1.9 MB/s  0:00:00
# Downloading ImageHash-4.3.2-py2.py3-none-any.whl (296 kB)
# Building wheels for collected packages: htmlmin
#   Building wheel for htmlmin (setup.py): started
#   Building wheel for htmlmin (setup.py): finished with status 'done'
#   Created wheel for htmlmin: filename=htmlmin-0.1.12-py3-none-any.whl size=27174 sha256=d8a51fbbee5ce7d953c2db6025c455bc133c56baecdbc2fd9b90820416156693
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\5f\d4\d7\4189b07b5902ee9f3ce0dbb14909fbe8037c39d6c63ffd49c9
# Successfully built htmlmin
# Installing collected packages: htmlmin, tangled-up-in-unicode, multimethod, markupsafe, joblib, imagehash, visions, phik, missingno, pandas-profiling
#
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#   Attempting uninstall: markupsafe
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#     Found existing installation: MarkupSafe 3.0.2
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#     Uninstalling MarkupSafe-3.0.2:
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#       Successfully uninstalled MarkupSafe-3.0.2
#    ---- -----------------------------------  1/10 [tangled-up-in-unicode]
#    ------------ ---------------------------  3/10 [markupsafe]
#   Attempting uninstall: joblib
#    ------------ ---------------------------  3/10 [markupsafe]
#     Found existing installation: joblib 1.4.2
#    ------------ ---------------------------  3/10 [markupsafe]
#     Uninstalling joblib-1.4.2:
#    ------------ ---------------------------  3/10 [markupsafe]
#       Successfully uninstalled joblib-1.4.2
#    ------------ ---------------------------  3/10 [markupsafe]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ---------------- -----------------------  4/10 [joblib]
#    ------------------------ ---------------  6/10 [visions]
#    ------------------------ ---------------  6/10 [visions]
#    ------------------------ ---------------  6/10 [visions]
#    ---------------------------- -----------  7/10 [phik]
#    ------------------------------------ ---  9/10 [pandas-profiling]
#    ------------------------------------ ---  9/10 [pandas-profiling]
#    ------------------------------------ ---  9/10 [pandas-profiling]
#    ------------------------------------ ---  9/10 [pandas-profiling]
#    ---------------------------------------- 10/10 [pandas-profiling]
#
# Successfully installed htmlmin-0.1.12 imagehash-4.3.2 joblib-1.1.1 markupsafe-2.1.5 missingno-0.5.2 multimethod-2.0 pandas-profiling-3.2.0 phik-0.12.5 tangled-up-in-unicode-0.2.0 visions-0.7.4
#   DEPRECATION: Building 'htmlmin' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'htmlmin'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# scikit-learn 1.7.1 requires joblib>=1.2.0, but you have joblib 1.1.1 which is incompatible.
# seleniumbase 4.41.1 requires MarkupSafe>=3.0.2; python_version >= "3.9", but you have markupsafe 2.1.5 which is incompatible.

# %%
# Upgrade ydata-profiling (the new name for pandas-profiling), numba, and visions
# !pip install --upgrade ydata-profiling numba visions
# Out:
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numba in c:\users\admin\anaconda3\lib\site-packages (0.60.0)
# Collecting numba
#   Downloading numba-0.61.2-cp312-cp312-win_amd64.whl.metadata (2.9 kB)
# Requirement already satisfied: visions in c:\users\admin\anaconda3\lib\site-packages (0.7.4)
# Collecting visions
#   Downloading visions-0.8.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (1.13.1)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.2.2)
# Requirement already satisfied: matplotlib<=3.10,>=3.5 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (3.9.2)
# Requirement already satisfied: pydantic>=2 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.8.2)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (6.0.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (3.1.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (1.26.4)
# Requirement already satisfied: htmlmin==0.1.12 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.1.12)
# Requirement already satisfied: phik<0.13,>=0.11.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.12.5)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (2.32.4)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (4.66.5)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.13.2)
# Collecting multimethod<2,>=1.4 (from ydata-profiling)
#   Downloading multimethod-1.12-py3-none-any.whl.metadata (9.6 kB)
# Requirement already satisfied: statsmodels<1,>=0.13.2 in c:\users\admin\anaconda3\lib\site-packages (from ydata-profiling) (0.14.2)
# Collecting typeguard<5,>=3 (from ydata-profiling)
#   Downloading typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Collecting imagehash==4.3.1 (from ydata-profiling)
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl.metadata (8.0 kB)
# Collecting wordcloud>=1.9.3 (from ydata-profiling)
#   Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl.metadata (3.5 kB)
# Collecting dacite>=1.8 (from ydata-profiling)
#   Downloading dacite-1.9.2-py3-none-any.whl.metadata (17 kB)
# Collecting numba
#   Downloading numba-0.61.0-cp312-cp312-win_amd64.whl.metadata (2.8 kB)
# Requirement already satisfied: PyWavelets in c:\users\admin\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (1.7.0)
# Requirement already satisfied: pillow in c:\users\admin\anaconda3\lib\site-packages (from imagehash==4.3.1->ydata-profiling) (10.4.0)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba)
#   Downloading llvmlite-0.44.0-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\admin\anaconda3\lib\site-packages (from visions) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\admin\anaconda3\lib\site-packages (from visions) (3.3)
# Collecting puremagic (from visions)
#   Downloading puremagic-1.30-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\appdata\roaming\python\python312\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling) (2023.3)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\admin\anaconda3\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling) (1.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling) (2025.8.3)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\admin\anaconda3\lib\site-packages (from statsmodels<1,>=0.13.2->ydata-profiling) (0.5.6)
# Requirement already satisfied: colorama in c:\users\admin\appdata\roaming\python\python312\site-packages (from tqdm<5,>=4.48.2->ydata-profiling) (0.4.6)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\admin\anaconda3\lib\site-packages (from typeguard<5,>=3->ydata-profiling) (4.14.1)
# Requirement already satisfied: six in c:\users\admin\anaconda3\lib\site-packages (from patsy>=0.5.6->statsmodels<1,>=0.13.2->ydata-profiling) (1.17.0)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (0.6.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\admin\anaconda3\lib\site-packages (from pydantic>=2->ydata-profiling) (2.20.1)
# Downloading ydata_profiling-4.16.1-py2.py3-none-any.whl (400 kB)
# Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Downloading numba-0.61.0-cp312-cp312-win_amd64.whl (2.8 MB)
#    ---------------------------------------- 0.0/2.8 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.8 MB ? eta -:--:--
#    ----------- ---------------------------- 0.8/2.8 MB 2.6 MB/s eta 0:00:01
#    ------------------ --------------------- 1.3/2.8 MB 2.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.6/2.8 MB 1.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.1/2.8 MB 2.0 MB/s eta 0:00:01
#    ------------------------------------- -- 2.6/2.8 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 2.8/2.8 MB 2.1 MB/s  0:00:01
# Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Downloading llvmlite-0.44.0-cp312-cp312-win_amd64.whl (30.3 MB)
#    ---------------------------------------- 0.0/30.3 MB ? eta -:--:--
#    ---------------------------------------- 0.3/30.3 MB ? eta -:--:--
#    - -------------------------------------- 1.0/30.3 MB 3.1 MB/s eta 0:00:10
#    -- ------------------------------------- 1.6/30.3 MB 2.7 MB/s eta 0:00:11
#    -- ------------------------------------- 2.1
MB 1.9 MB/s eta 0:00:04
#    ------------------------------- -------- 23.9/30.3 MB 1.9 MB/s eta 0:00:04
#    -------------------------------- ------- 24.4/30.3 MB 1.9 MB/s eta 0:00:04
#    -------------------------------- ------- 24.9/30.3 MB 1.9 MB/s eta 0:00:03
#    --------------------------------- ------ 25.4/30.3 MB 1.9 MB/s eta 0:00:03
#    --------------------------------- ------ 25.7/30.3 MB 1.9 MB/s eta 0:00:03
#    ---------------------------------- ----- 26.2/30.3 MB 1.9 MB/s eta 0:00:03
#    ----------------------------------- ---- 26.7/30.3 MB 1.9 MB/s eta 0:00:02
#    ----------------------------------- ---- 27.3/30.3 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------ --- 27.8/30.3 MB 1.9 MB/s eta 0:00:02
#    ------------------------------------- -- 28.3/30.3 MB 1.9 MB/s eta 0:00:02
#    -------------------------------------- - 28.8/30.3 MB 1.9 MB/s eta 0:00:01
#    -------------------------------------- - 29.4/30.3 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------  29.9/30.3 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 30.3/30.3 MB 2.0 MB/s  0:00:15
# Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Downloading wordcloud-1.9.4-cp312-cp312-win_amd64.whl (301 kB)
# Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Installing collected packages: puremagic, typeguard, multimethod, llvmlite, dacite, numba, imagehash, wordcloud, visions, ydata-profiling
#
#   Attempting uninstall: multimethod
#
#     Found existing installation: multimethod 2.0
#
#     Uninstalling multimethod-2.0:
#
#       Successfully uninstalled multimethod-2.0
#
#    -------- -------------------------------  2/10 [multimethod]
#   Attempting uninstall: llvmlite
#    -------- -------------------------------  2/10 [multimethod]
#     Found existing installation: llvmlite 0.43.0
#    -------- -------------------------------  2/10 [multimethod]
#     Uninstalling llvmlite-0.43.0:
#    -------- -------------------------------  2/10 [multimethod]
#       Successfully uninstalled llvmlite-0.43.0
#    -------- -------------------------------  2/10 [multimethod]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ------------ ---------------------------  3/10 [llvmlite]
#    ---------------- -----------------------  4/10 [dacite]
#   Attempting uninstall: numba
#    ---------------- -----------------------  4/10 [dacite]
#     Found existing installation: numba 0.60.0
#    ---------------- -----------------------  4/10 [dacite]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#     Uninstalling numba-0.60.0:
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#       Successfully uninstalled numba-0.60.0
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#    -------------------- -------------------  5/10 [numba]
#   Attempting uninstall: imagehash
#    -------------------- -------------------  5/10 [numba]
#     Found existing installation: ImageHash 4.3.2
#    -------------------- -------------------  5/10 [numba]
#     Uninstalling ImageHash-4.3.2:
#    -------------------- -------------------  5/10 [numba]
#       Successfully uninstalled ImageHash-4.3.2
#    -------------------- -------------------  5/10 [numba]
#    ------------------------ ---------------  6/10 [imagehash]
#   Attempting uninstall: visions
#    ------------------------ ---------------  6/10 [imagehash]
#    -------------------------------- -------  8/10 [visions]
#     Found existing installation: visions 0.7.4
#    -------------------------------- -------  8/10 [visions]
#     Uninstalling visions-0.7.4:
#    -------------------------------- -------  8/10 [visions]
#    -------------------------------- -------  8/10 [visions]
#       Successfully uninstalled visions-0.7.4
#    -------------------------------- -------  8/10 [visions]
#    -------------------------------- -------  8/10 [visions]
#    -------------------------------- -------  8/10 [visions]
#    -------------------------------- -------  8/10 [visions]
#    -------------------------------- -------  8/10 [visions]
#    ------------------------------------ ---  9/10 [ydata-profiling]
#    ------------------------------------ ---  9/10 [ydata-profiling]
#    ------------------------------------ ---  9/10 [ydata-profiling]
#    ------------------------------------ ---  9/10 [ydata-profiling]
#    ------------------------------------ ---  9/10 [ydata-profiling]
#    ------------------------------------ ---  9/10 [ydata-profiling]
#    ---------------------------------------- 10/10 [ydata-profiling]
#
# Successfully installed dacite-1.9.2 imagehash-4.3.1 llvmlite-0.44.0 multimethod-1.12 numba-0.61.0 puremagic-1.30 typeguard-4.4.4 visions-0.8.1 wordcloud-1.9.4 ydata-profiling-4.16.1
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADMIN\anaconda3\Lib\site-packages\~lvmlite'.
#   You can safely remove it manually.
#   WARNING: Failed to remove contents in a temporary directory 'C:\Users\ADMIN\anaconda3\Lib\site-packages\~umba'.
#   You can safely remove it manually.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires visions[type_image_path]==0.7.4, but you have visions 0.8.1 which is incompatible.
